# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
df = pd.read_csv('./hardware_monitor_data.csv')

# %%
df.shape
# Out:
# (72000, 7)

# %%
df
# Out:
#                         timestamp  cpu_temperature  cpu_usage  cpu_load  \
# 0      2024-11-25 19:51:45.167731        96.870324  10.800000      0.00
# 1      2024-11-25 19:51:45.557674              NaN   8.200000      0.00
# 2      2024-11-25 19:51:45.771979              NaN  91.951109      0.00
# 3      2024-11-25 19:51:45.986364              NaN  94.088428      0.00
# 4      2024-11-25 19:51:46.198601              NaN   8.800000      0.00
# ...                           ...              ...        ...       ...
# 71995  2024-11-26 00:11:51.067665              NaN   3.200000      0.73
# 71996  2024-11-26 00:11:51.283787              NaN   0.000000      0.73
# 71997  2024-11-26 00:11:51.496874              NaN   1.900000      0.73
# 71998  2024-11-26 00:11:51.712379              NaN   1.800000      0.73
# 71999  2024-11-26 00:11:51.952863              NaN   1.000000      0.73
#
#        memory_usage  battery_level  cpu_power
# 0              57.1      94.000000        NaN
# ...

# %%
df['cpu_temperature'].isna().sum()
# Out:
# 64837

# %%
df['cpu_power'].isna().sum()
# Out:
# 64845

# %%
df['cpu_usage'].isna().sum()
# Out:
# 0

# %%
df['cpu_load'].isna().sum()
# Out:
# 0

# %%
df['memory_usage'].isna().sum()
# Out:
# 0

# %%
df['battery_level'].isna().sum()
# Out:
# 0

# %%
df['timestamp'].isna().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

plt.plot(df['cpu_usage'][:2000],)
plt.ylabel('cpu usage')
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')

# %%
plt.plot(df['cpu_load'],)
plt.ylabel('cpu load')
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')

# %%
plt.plot(df['cpu_usage'][:2000],)
plt.ylabel('cpu usage')
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')

# %%
plt.plot(df['cpu_power'],)
plt.ylabel('cpu power')
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')

# %%
plt.plot(df['cpu_temperature'],)
plt.ylabel('cpu temperature')
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')
